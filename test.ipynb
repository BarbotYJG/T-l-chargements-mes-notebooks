# %%
# import modules
from matplotlib import pyplot as plt
import matplotlib.cm as cm
import numpy.ma as ma
import numpy as np
# %matplotlib inline

# %%
# add the path 

VORTfile = '/home/barboty/Work/Vort/NATL60LAB-MJM155_y2007m12d30.1d_CURLOVERF.nc'

# %%
from netCDF4 import Dataset
f = Dataset(VORTfile, "r", format="NETCDF4")
VORT = f.variables['socurloverf']
VORT.shape
# Out:
# (1, 748, 942)

# %%
plt.figure(figsize=(20,15))
plt.pcolormesh(ma.masked_invalid(np.squeeze(VORT)), vmin=-0.6, vmax=0.6)
plt.colorbar()
